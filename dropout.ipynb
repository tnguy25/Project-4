# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("data.csv",sep=";")
df
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                17                  5     171
# 1                  1                15                  1    9254
# 2                  1                 1                  5    9070
# 3                  1                17                  2    9773
# 4                  2                39                  1    8014
# ...              ...               ...                ...     ...
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance\t  Previous qualification  \
# 0                                1                       1
# ...

# %%
# print the shape of the DataFrame, the number of rows and columns

print(f'The data frame has {df.shape[0]} rows and {df.shape[1]} columns.')
# Out:
# The data frame has 4424 rows and 37 columns.

# %%
# show the general information of the data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance	                     4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   int64
#  8   Mother's qualification                          4424 non-null   int64
# ...

# %%
# check if there are null values in the data

df.isnull().sum()
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance\t                      0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Admission grade                                   0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# ...

# %%
# general statistics of the data

df.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571         18.669078           1.727848  8856.642631
# std          0.605747         17.484682           1.313793  2063.566416
# min          1.000000          1.000000           0.000000    33.000000
# 25%          1.000000          1.000000           1.000000  9085.000000
# 50%          1.000000         17.000000           1.000000  9238.000000
# 75%          1.000000         39.000000           2.000000  9556.000000
# max          6.000000         57.000000           9.000000  9991.000000
#
#        Daytime/evening attendance\t  Previous qualification  \
# count                   4424.000000             4424.000000
# mean                       0.890823                4.577758
# std                        0.311897               10.216592
# min                        0.000000                1.000000
# ...

# %%
import seaborn as sns
import matplotlib.gridspec as gridspec

# plot the distribution of each variable

fig = plt.figure(figsize=(20, 20))
# give more space between the plots
fig.subplots_adjust(hspace=0.5, wspace=0.4)
gs = gridspec.GridSpec(10, 4)

# foor loop to add each plot (remove the last column because it is the target variable)
for i, col in enumerate(df.columns[:-1]):
    ax = fig.add_subplot(gs[i])
    sns.histplot(df[col], ax=ax)
    ax.set_xlabel('')
    ax.set_title('feature: ' + col)

plt.show()
# Out:
# c:\Users\uwagb\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# correlation analysis between variables
# remove the last column because it is the target variable

corr = df.iloc[:, :-1].corr()
corr
# Out:
#                                                 Marital status  \
# Marital status                                        1.000000
# Application mode                                      0.264006
# Application order                                    -0.125854
# Course                                                0.046365
# Daytime/evening attendance\t                         -0.274939
# Previous qualification                                0.062529
# Previous qualification (grade)                       -0.022406
# Nacionality                                          -0.008843
# Mother's qualification                                0.193163
# Father's qualification                                0.130353
# Mother's occupation                                   0.034994
# Father's occupation                                   0.031609
# Admission grade                                      -0.004771
# Displaced                                            -0.234886
# ...

# %%
# Plotting a correlation matrix 
fig = plt.figure(figsize=(10, 8))

sns.heatmap(df.corr(),annot=False, cmap='RdBu', center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.show
# Out:
# C:\Users\uwagb\AppData\Local\Temp\ipykernel_32956\2067183693.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=False, cmap='RdBu', center=0,
# c:\Users\uwagb\anaconda3\lib\site-packages\seaborn\utils.py:84: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.draw()
# <function matplotlib.pyplot.show(close=None, block=None)>
# c:\Users\uwagb\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 9 (	) missing from current font.
#   func(*args, **kwargs)
# c:\Users\uwagb\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import textwrap

# %%
# plot the relationship betwee each variables and the target variable (which is the last column). Using boxplot

fig = plt.figure(figsize=(20, 20))
# give more space between the plots
fig.subplots_adjust(hspace=0.6, wspace=0.5)
gs = gridspec.GridSpec(10, 4)

# foor loop to add each plot (remove the last column because it is the target variable)
for i, col in enumerate(df.columns[:-1]):
    ax = fig.add_subplot(gs[i])
    sns.boxplot(x=df['Target'], y=df[col], ax=ax)
    ax.set_xlabel('')
    # wrap the y labels
    ax.set_ylabel(textwrap.fill(col, 15))
    #ax.set_title('feature: ' + col)

plt.show()
